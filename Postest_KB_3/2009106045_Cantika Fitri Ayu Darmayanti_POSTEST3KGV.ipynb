# %% [markdown]
# ## CANTIKA FITRI AYU DARMAYANTI 2009106045

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.read_csv('test.csv')
df.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        50000 non-null  object
#  1   Customer_ID               50000 non-null  object
#  2   Month                     50000 non-null  object
#  3   Name                      44985 non-null  object
#  4   Age                       50000 non-null  object
#  5   SSN                       50000 non-null  object
#  6   Occupation                50000 non-null  object
#  7   Annual_Income             50000 non-null  object
#  8   Monthly_Inhand_Salary     42502 non-null  float64
#  9   Num_Bank_Accounts         50000 non-null  int64
#  10  Num_Credit_Card           50000 non-null  int64
#  11  Interest_Rate             50000 non-null  int64
#  12  Num_of_Loan               50000 non-null  object
# ...

# %%
#Grafik Pie
grafik_pie = df['Occupation'].value_counts().rename_axis('occupation').reset_index(name='Id_count')
plt.figure(figsize=(10, 12))
plt.pie(grafik_pie.Id_count, labels=data_pie.occupation, startangle=90, autopct='%.1f%%')
plt.title('occupation')
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# Dari data diatas dapat diketahui bahwa pekerjaan terbanyak untuk penilaian kredit adalah tidak bekerja (tidak diketahui)

# %%
#Grafik Batang
plt.figure(figsize = (10, 10))
Attrplot=sns.countplot(x = 'Credit_Mix', data = df)
plt.title("Credit Mix")
plt.ylabel('Count (Jumlah)')
plt.xlabel('Credit Mix')
plt.show()

# %% [markdown]
# Dari data diatas dapat dikeathui bahwa penilaian credit_mix terbanyak yaitu nilai standar dengan data lebih dari 17500, baik dengan 12500 data, nilai buruk dan tidak ternilai dibawah 10000 data

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x='Credit_Mix',data=df, hue='Month')
plt.title('Data Credit Mix dan Bulan')
plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.5)
plt.ylabel('Count (Jumlah)')
plt.xlabel('Credit Mix')
plt.show()

# %% [markdown]
# Dari data diatas untuk credit mix good nilainya sama pada bulan september, november dan desember. Credit mix pada - banyak pada bulan oktober. Credit mix standar nilai pada bulan september dan desember sama dan pada credit mix bad nilai terbanyak bad pada bulan september. Untuk keseluruhan, mulai dari bulan september-desember nilai terbanyak adalah standar

# %%
sns.boxplot(x='Month',data=df,y='Monthly_Inhand_Salary')
plt.title('Gaji Bulanan vs Bulan')
plt.ylabel('Gaji Bulanan')
plt.xlabel('Bulan')
# Out:
# Text(0.5, 0, 'Bulan')

# %% [markdown]
# Dari data diatas dapat diketahui bahwa pada bulan september-desember gaji bulanan nilainya sama deangan masing-masing 6000 data

# %%
#Grafik HeatMap
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,cmap='Purples', center=0)
plt.title('Korelasi antar atribut pada klasifikasi credit score')
plt.show()

# %% [markdown]
# Dari grafikrafik heatMapdiatas menampilkan pemetaan dengan menampilkan dataset test pada credit score clasification yang menjelaskan korelasi antar variabel yang semakin tinggi angka suatu kelompok data maka warnanya akan semakin gelap.

# %%
df.to_csv("POSTEST3KPRAKKB.csv", index=False)
